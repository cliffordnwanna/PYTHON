# %% [markdown]
#    VARIABLE DESCRPTION:
#
#    small pizza = sp.
#
#    medium pizza = mp.
#
#    large pizza = lp.
#
#    pepperoni + small pizza = psp.
#
#    pepperoni + meduim pizza = pmp.
#
#    pepperoni + large pizza = plp.
#
#    extra cheese = ec.

# %%
#assignment of variables
sp, mp, lp = 15, 20, 25
psp, pmp, plp = 17, 23, 28
ec = 1

# %%
print("Welcome To Python Pizza Deliveries")
size = input("What size of pizza do you want? S, M or L \n")
pepperoni = input("Add peppperoni? Y or N \n")
extra_cheese = input("Add extra cheese? Y or N \n")

if size == "S" and pepperoni == "Y" and extra_cheese == "Y":
    print(f"Your final bill is: {psp + ec} ")
elif size == "S" and pepperoni == "N" and extra_cheese == "N":
    print(f"Your final bill is: {sp} ")
elif size == "S" and pepperoni == "Y" and extra_cheese == "N":
    print(f"Your final bill is: {psp} ")
elif size == "S" and pepperoni == "N" and extra_cheese == "Y":
    print(f"Your final bill is: {sp + ec} ")


elif size == "M" and pepperoni == "Y" and extra_cheese == "Y":
    print(f"Your final bill is: {pmp + ec} ")
elif size == "M" and pepperoni == "N" and extra_cheese == "N":
    print(f"Your final bill is: {mp} ")
elif size == "M" and pepperoni == "Y" and extra_cheese == "N":
    print(f"Your final bill is: {pmp} ")
elif size == "M" and pepperoni == "N" and extra_cheese == "Y":
    print(f"Your final bill is: {mp + ec} ")

if size == "L" and pepperoni == "Y" and extra_cheese == "Y":
    print(f"Your final bill is: {plp + ec} ")
elif size == "L" and pepperoni == "N" and extra_cheese == "N":
    print(f"Your final bill is: {lp} ")
elif size == "L" and pepperoni == "Y" and extra_cheese == "N":
    print(f"Your final bill is: {plp} ")
elif size == "L" and pepperoni == "N" and extra_cheese == "Y":
    print(f"Your final bill is: {lp + ec} ")
# Out:
# Welcome To Python Pizza Deliveries
# What size of pizza do you want? S, M or L
# L
# Add peppperoni? Y or N
# Y
# Add extra cheese? Y or N
# Y
# Your final bill is: 29
