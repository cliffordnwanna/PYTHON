# %%
# Create four basic mathematical functions: 'add', 'subtract', 'multiply', and 'divide' that take in two numbers
# and return the result of the operation
def add(x,y):
    return x + y
def subtract(x,y):
    return x - y
def multiply(x,y):
    return x * y
def divide(x,y):
    return x / y

#Create a dictionary 'operations' that assigns the functions to their corresponding operation symbols.
operations = {"+": add, "-": subtract, "*": multiply, "/": divide}

#create a variable that stores the user's first input
first_number = float(input("Input the first number: "))



# Use a for loop to print the available operation symbols.
def operation_symbols(operations):
    list = []
    for key in operations.keys():
        list.append(key)
    return list
# Create a function 'calculator' that prompts the user to input the first number
def calculator():
    first_number

process = True
while process: # Create a while loop that will continue to run until the user chooses to end the current calculation.
    calculator()
    user_input = str(input("select '+','-','*','/','quit' to exit\n")) # prompt the user to select an operation symbol.
    if user_input == 'quit':
        break
    elif user_input == "+" or "-" or "*" or "/":
        second_number = float(input("Input the second number : ")) # Prompt the user to input the second number.
    else:
        print("unrecognised arithmetic expression")
    if user_input in operations:
        calculation_function = operations[user_input] #Use the dictionary to retrieve the function that correspondsto the
                                                    #selected operation symbol and store it in a variable 'calculation_function'

        answer = calculation_function(first_number, second_number) #Perform the calculation by calling the 'calculation_function'
                                                            #on the two input numbers and store the result in a variable 'answer'.

        print(f"{first_number} {user_input} {second_number} = {answer}") #Print the equation and the result of the calculation.

        #Ask the user if they would like to continue using the result as the first number for further calculations.
        should_continue = str(input("Continue using the result as the first number for further calculations ?. YES/NO/QUIT\n"))
    else:
        print(f"'{user_input}' is not allowed.")
    if should_continue == "YES": #If the user chooses to continue, update the 'first_number' variable to the value of 'answer'.
        first_number = answer
        print(f"result = {first_number}")
        continue

    #If the user chooses to start a new calculation, set the 'should_continue' variable to false
    elif should_continue == "NO":
                              first_number = float(input("Enter the first number: "))
                              continue # call the  'calculator' function to start a new calculation.
    else:
        break
